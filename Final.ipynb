# %%
import tensorflow as tf
import numpy as np
from sklearn import datasets
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn import datasets
from sklearn.metrics import mean_absolute_error
from sklearn import model_selection

#gets rid of wierd warning messages
tf.logging.set_verbosity(tf.logging.ERROR)

#how you set the random seed in tensorflow as opposed to numpy
RANDOM_SEED = 42
tf.set_random_seed(RANDOM_SEED)

def init_weights(shape):
    """ Weight initialization """
    weights = tf.random_normal(shape, stddev=0.1)
    return tf.Variable(weights)

# %%
#Using 3 hidden layers
def forwardprop(X, w_1, w_2, w_3):
    """
    Forward-propagation.
    IMPORTANT: yhat is not softmax since TensorFlow's softmax_cross_entropy_with_logits() does that internally.
    """
    #sigmoid produces new vector of numbers 
    h    = tf.nn.sigmoid(tf.matmul(X, w_1))# The \sigma function
    h2    = tf.nn.sigmoid(tf.matmul(h, w_2))
    #do matrix multiplication 
    yhat = tf.matmul(h2, w_3)  # The \varphi function
    return yhat

# %%
#Reading in training features, training labels, and test features
train_features = pd.read_csv('DengAI_Predicting_Disease_Spread_-_Training_Data_Features.csv',
                             index_col=[0,1,2])

train_labels = pd.read_csv('DengAI_Predicting_Disease_Spread_-_Training_Data_Labels.csv',
                           index_col=[0,1,2])

test_features = pd.read_csv('DengAI_Predicting_Disease_Spread_-_Test_Data_Features.csv',
                           index_col=[0,1,2])

# %%
#Seperate data for San Juan
sj_train_features = train_features.loc['sj']
sj_train_labels = train_labels.loc['sj']

#Separate data for Iquitos
iq_train_features = train_features.loc['iq']
iq_train_labels = train_labels.loc['iq']

#test data for sj
sj_test_features = test_features.loc['sj']

#test data for iq
iq_test_features = test_features.loc['iq']

# %%
#Fill NA/NaN values using the specified method
sj_train_features.fillna(method='ffill', inplace=True)
iq_train_features.fillna(method='ffill', inplace=True)
iq_test_features.fillna(method='ffill', inplace=True)
sj_test_features.fillna(method='ffill', inplace=True)
# Out:
# /Users/hannahsaghir/anaconda/lib/python3.6/site-packages/pandas/core/frame.py:2754: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)

# %%
#Creating X and y values for sj and iq that will be trained
X_sj = sj_train_features[["precipitation_amt_mm", "station_avg_temp_c", 'ndvi_ne', 'ndvi_nw', 'ndvi_se', 
                                'reanalysis_air_temp_k', 'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k', 
                                'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k', 
                                'reanalysis_precip_amt_kg_per_m2', 'reanalysis_relative_humidity_percent', 
                                'reanalysis_sat_precip_amt_mm', 'reanalysis_specific_humidity_g_per_kg', 
                                'reanalysis_tdtr_k', 'station_diur_temp_rng_c', 'station_max_temp_c', 
                                'station_min_temp_c', 'station_precip_mm']]
y_sj = sj_train_labels['total_cases']
X_iq = iq_train_features[["precipitation_amt_mm", "station_avg_temp_c", 'ndvi_ne', 'ndvi_nw', 'ndvi_se', 
                                'reanalysis_air_temp_k', 'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k', 
                                'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k', 
                                'reanalysis_precip_amt_kg_per_m2', 'reanalysis_relative_humidity_percent', 
                                'reanalysis_sat_precip_amt_mm', 'reanalysis_specific_humidity_g_per_kg', 
                                'reanalysis_tdtr_k', 'station_diur_temp_rng_c', 'station_max_temp_c', 
                                'station_min_temp_c', 'station_precip_mm']]
y_iq = iq_train_labels['total_cases']


#test X and y values
X_sj_tests2 = sj_test_features[["precipitation_amt_mm", "station_avg_temp_c", 'ndvi_ne', 'ndvi_nw', 'ndvi_se', 
                                'reanalysis_air_temp_k', 'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k', 
                                'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k', 
                                'reanalysis_precip_amt_kg_per_m2', 'reanalysis_relative_humidity_percent', 
                                'reanalysis_sat_precip_amt_mm', 'reanalysis_specific_humidity_g_per_kg', 
                                'reanalysis_tdtr_k', 'station_diur_temp_rng_c', 'station_max_temp_c', 
                                'station_min_temp_c', 'station_precip_mm']]

X_iq_tests2 = iq_test_features[["precipitation_amt_mm", "station_avg_temp_c", 'ndvi_ne', 'ndvi_nw', 'ndvi_se', 
                                'reanalysis_air_temp_k', 'reanalysis_avg_temp_k', 'reanalysis_dew_point_temp_k', 
                                'reanalysis_max_air_temp_k', 'reanalysis_min_air_temp_k', 
                                'reanalysis_precip_amt_kg_per_m2', 'reanalysis_relative_humidity_percent', 
                                'reanalysis_sat_precip_amt_mm', 'reanalysis_specific_humidity_g_per_kg', 
                                'reanalysis_tdtr_k', 'station_diur_temp_rng_c', 'station_max_temp_c', 
                                'station_min_temp_c', 'station_precip_mm']]

# %%
# iq data
X_iq_test = X_iq[-100:] #Last 100 items
X_iq_train = X_iq[:-100] #First 100 items

y_iq_test = y_iq[-100:]
y_iq_train = y_iq[:-100]

y_iq_train = y_iq_train.reshape((-1,1))
y_iq_test = y_iq_test.reshape((-1,1))

# sj data
X_sj_test = X_sj[-100:]
X_sj_train = X_sj[:-100]

y_sj_test = y_sj[-100:]
y_sj_train = y_sj[:-100]

y_sj_train = y_sj_train.reshape((-1,1))
y_sj_test = y_sj_test.reshape((-1,1))
# Out:
# /Users/hannahsaghir/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:8: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# /Users/hannahsaghir/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:9: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# /Users/hannahsaghir/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:18: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# /Users/hannahsaghir/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:19: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead

# %%
# Layer's sizes
x_size = X_iq_train.shape[1]   # Number of input nodes: 4 features and 1 bias
h_size = 32              # Number of hidden nodes in the middle which is up to us
y_size = 1   # Number of outcomes (3 iris flowers)

# Layer's sizes
x_size = X_sj_train.shape[1]   # Number of input nodes: 4 features and 1 bias
h_size = 256             # Number of hidden nodes in the middle which is up to us
y_size = 1   # Number of outcomes (3 iris flowers)

# %%
# Symbols iq
X_iq = tf.placeholder("float", shape=[None, x_size])
y_iq = tf.placeholder("float", shape=[None, y_size])

# Symbols sj
X_sj = tf.placeholder("float", shape=[None, x_size])
y_sj = tf.placeholder("float", shape=[None, y_size])

# %%
# Weight initializations to create two varibles to train and do multiplication with
w_1iq = init_weights((x_size, h_size))
w_2iq = init_weights((h_size, h_size))
w_3iq = init_weights((h_size, y_size))

w_1sj = init_weights((x_size, h_size))
w_2sj = init_weights((h_size, h_size))
w_3sj = init_weights((h_size, y_size))

# %%
# Forward propagation
#takes input and two sets of weights
yhat_iq   = forwardprop(X_iq, w_1iq, w_2iq, w_3iq)
yhat_sj    = forwardprop(X_sj, w_1sj, w_2sj, w_3sj)
predict_iq = tf.to_int64(yhat_iq)
predict_sj = tf.to_int64(yhat_sj)

# %%
# Backward propagation
#the one loss function you always use when making classifications with tf
cost_iq    = tf.losses.mean_squared_error(labels=y_iq, predictions=yhat_iq)
#train op we saw on slides to minimize cost 
updates_iq = tf.train.GradientDescentOptimizer(0.0000003).minimize(cost_iq)


# Backward propagation
#the one loss function you always use when making classifications with tf
cost_sj   = tf.losses.mean_squared_error(labels=y_sj, predictions=yhat_sj)
#train op we saw on slides to minimize cost 
updates_sj = tf.train.GradientDescentOptimizer(0.0000003).minimize(cost_sj)

# %%
# Run SGD
#everytime you create session you need to run that line of code 
sess = tf.Session()
init = tf.global_variables_initializer()
sess.run(init)

# %%
#100 gradient descent updates and run batches of size one; example at a time 

#for iq
for epoch in range(100):
        # Train with each example
        for i in range(len(X_iq_train)):
            sess.run(updates_iq, feed_dict={X_iq: X_iq_train[i: i + 1], y_iq: y_iq_train[i: i + 1]})
            
        train_accuracy = mean_absolute_error(y_iq_train,
                                 sess.run(predict_iq, feed_dict={X_iq: X_iq_train}))
        test_accuracy  = mean_absolute_error(y_iq_test,
                                 sess.run(predict_iq, feed_dict={X_iq: X_iq_test}))
#printing out accuracy
        print("Epoch = %d, train accuracy = %.2f, test accuracy = %.2f"
              % (epoch + 1,  train_accuracy, test_accuracy))
# Out:
# Epoch = 1, train accuracy = 7.03, test accuracy = 9.83
# Epoch = 2, train accuracy = 6.93, test accuracy = 9.68
# Epoch = 3, train accuracy = 6.55, test accuracy = 9.15
# Epoch = 4, train accuracy = 6.45, test accuracy = 8.97
# Epoch = 5, train accuracy = 6.45, test accuracy = 8.97
# Epoch = 6, train accuracy = 6.45, test accuracy = 8.97
# Epoch = 7, train accuracy = 6.45, test accuracy = 8.97
# Epoch = 8, train accuracy = 6.39, test accuracy = 8.92
# Epoch = 9, train accuracy = 6.15, test accuracy = 8.41
# Epoch = 10, train accuracy = 6.08, test accuracy = 8.29
# Epoch = 11, train accuracy = 6.06, test accuracy = 8.27
# Epoch = 12, train accuracy = 6.06, test accuracy = 8.27
# Epoch = 13, train accuracy = 6.06, test accuracy = 8.27
# Epoch = 14, train accuracy = 6.06, test accuracy = 8.27
# Epoch = 15, train accuracy = 6.06, test accuracy = 8.27
# Epoch = 16, train accuracy = 6.00, test accuracy = 8.13
# Epoch = 17, train accuracy = 5.87, test accuracy = 7.88
# Epoch = 18, train accuracy = 5.85, test accuracy = 7.86
# Epoch = 19, train accuracy = 5.85, test accuracy = 7.80
# Epoch = 20, train accuracy = 5.84, test accuracy = 7.79
# Epoch = 21, train accuracy = 5.84, test accuracy = 7.79
# Epoch = 22, train accuracy = 5.84, test accuracy = 7.79
# Epoch = 23, train accuracy = 5.84, test accuracy = 7.79
# Epoch = 24, train accuracy = 5.84, test accuracy = 7.79
# Epoch = 25, train accuracy = 5.84, test accuracy = 7.79
# Epoch = 26, train accuracy = 5.83, test accuracy = 7.79
# Epoch = 27, train accuracy = 5.77, test accuracy = 7.65
# Epoch = 28, train accuracy = 5.73, test accuracy = 7.52
# Epoch = 29, train accuracy = 5.75, test accuracy = 7.50
# Epoch = 30, train accuracy = 5.75, test accuracy = 7.44
# Epoch = 31, train accuracy = 5.75, test accuracy = 7.43
# Epoch = 32, train accuracy = 5.75, test accuracy = 7.41
# Epoch = 33, train accuracy = 5.76, test accuracy = 7.41
# Epoch = 34, train accuracy = 5.76, test accuracy = 7.41
# Epoch = 35, train accuracy = 5.76, test accuracy = 7.41
# Epoch = 36, train accuracy = 5.76, test accuracy = 7.41
# Epoch = 37, train accuracy = 5.76, test accuracy = 7.41
# Epoch = 38, train accuracy = 5.76, test accuracy = 7.41
# Epoch = 39, train accuracy = 5.76, test accuracy = 7.41
# Epoch = 40, train accuracy = 5.76, test accuracy = 7.41
# Epoch = 41, train accuracy = 5.77, test accuracy = 7.39
# Epoch = 42, train accuracy = 5.73, test accuracy = 7.35
# Epoch = 43, train accuracy = 5.73, test accuracy = 7.31
# Epoch = 44, train accuracy = 5.74, test accuracy = 7.27
# Epoch = 45, train accuracy = 5.74, test accuracy = 7.28
# Epoch = 46, train accuracy = 5.75, test accuracy = 7.26
# Epoch = 47, train accuracy = 5.77, test accuracy = 7.22
# Epoch = 48, train accuracy = 5.77, test accuracy = 7.20
# Epoch = 49, train accuracy = 5.77, test accuracy = 7.21
# Epoch = 50, train accuracy = 5.78, test accuracy = 7.19
# Epoch = 51, train accuracy = 5.78, test accuracy = 7.19
# Epoch = 52, train accuracy = 5.78, test accuracy = 7.19
# Epoch = 53, train accuracy = 5.78, test accuracy = 7.19
# Epoch = 54, train accuracy = 5.78, test accuracy = 7.19
# Epoch = 55, train accuracy = 5.78, test accuracy = 7.19
# Epoch = 56, train accuracy = 5.78, test accuracy = 7.19
# Epoch = 57, train accuracy = 5.78, test accuracy = 7.19
# Epoch = 58, train accuracy = 5.78, test accuracy = 7.19
# Epoch = 59, train accuracy = 5.78, test accuracy = 7.19
# Epoch = 60, train accuracy = 5.78, test accuracy = 7.19
# Epoch = 61, train accuracy = 5.78, test accuracy = 7.19
# Epoch = 62, train accuracy = 5.78, test accuracy = 7.19
# Epoch = 63, train accuracy = 5.78, test accuracy = 7.19
# Epoch = 64, train accuracy = 5.78, test accuracy = 7.19
# Epoch = 65, train accuracy = 5.78, test accuracy = 7.19
# Epoch = 66, train accuracy = 5.77, test accuracy = 7.20
# Epoch = 67, train accuracy = 5.78, test accuracy = 7.24
# Epoch = 68, train accuracy = 5.79, test accuracy = 7.27
# Epoch = 69, train accuracy = 5.80, test accuracy = 7.29
# Epoch = 70, train accuracy = 5.83, test accuracy = 7.28
# Epoch = 71, train accuracy = 5.83, test accuracy = 7.28
# Epoch = 72, train accuracy = 5.83, test accuracy = 7.27
# Epoch = 73, train accuracy = 5.83, test accuracy = 7.26
# Epoch = 74, train accuracy = 5.84, test accuracy = 7.26
# Epoch = 75, train accuracy = 5.85, test accuracy = 7.27
# Epoch = 76, train accuracy = 5.85, test accuracy = 7.30
# Epoch = 77, train accuracy = 5.85, test accuracy = 7.29
# Epoch = 78, train accuracy = 5.86, test accuracy = 7.29
# Epoch = 79, train accuracy = 5.88, test accuracy = 7.27
# Epoch = 80, train accuracy = 5.90, test accuracy = 7.27
# Epoch = 81, train accuracy = 5.90, test accuracy = 7.26
# Epoch = 82, train accuracy = 5.92, test accuracy = 7.27
# Epoch = 83, train accuracy = 5.92, test accuracy = 7.26
# Epoch = 84, train accuracy = 5.92, test accuracy = 7.26
# Epoch = 85, train accuracy = 5.92, test accuracy = 7.25
# Epoch = 86, train accuracy = 5.92, test accuracy = 7.25
# Epoch = 87, train accuracy = 5.93, test accuracy = 7.26
# Epoch = 88, train accuracy = 5.93, test accuracy = 7.26
# Epoch = 89, train accuracy = 5.93, test accuracy = 7.26
# Epoch = 90, train accuracy = 5.93, test accuracy = 7.26
# Epoch = 91, train accuracy = 5.93, test accuracy = 7.26
# Epoch = 92, train accuracy = 5.93, test accuracy = 7.26
# Epoch = 93, train accuracy = 5.93, test accuracy = 7.25
# Epoch = 94, train accuracy = 5.93, test accuracy = 7.25
# Epoch = 95, train accuracy = 5.94, test accuracy = 7.25
# Epoch = 96, train accuracy = 5.94, test accuracy = 7.25
# Epoch = 97, train accuracy = 5.94, test accuracy = 7.25
# Epoch = 98, train accuracy = 5.95, test accuracy = 7.25
# Epoch = 99, train accuracy = 5.95, test accuracy = 7.25
# Epoch = 100, train accuracy = 5.94, test accuracy = 7.25

# %%
#100 gradient descent updates and run batches of size one; example at a time 

#for sj
for epoch in range(100):
        # Train with each example
        for i in range(len(X_sj_train)):
            sess.run(updates_sj, feed_dict={X_sj: X_sj_train[i: i + 1], y_sj: y_sj_train[i: i + 1]})
            
        train_accuracy = mean_absolute_error(y_sj_train,
                                 sess.run(predict_sj, feed_dict={X_sj: X_sj_train}))
        test_accuracy  = mean_absolute_error(y_sj_test,
                                 sess.run(predict_sj, feed_dict={X_sj: X_sj_test}))
#printing out accuracy
        print("Epoch = %d, train accuracy = %.2f, test accuracy = %.2f"
              % (epoch + 1,  train_accuracy, test_accuracy))
# Out:
# Epoch = 1, train accuracy = 33.33, test accuracy = 22.95
# Epoch = 2, train accuracy = 32.26, test accuracy = 21.88
# Epoch = 3, train accuracy = 30.78, test accuracy = 20.49
# Epoch = 4, train accuracy = 30.04, test accuracy = 19.83
# Epoch = 5, train accuracy = 28.82, test accuracy = 18.65
# Epoch = 6, train accuracy = 28.27, test accuracy = 18.17
# Epoch = 7, train accuracy = 27.78, test accuracy = 17.73
# Epoch = 8, train accuracy = 27.34, test accuracy = 17.41
# Epoch = 9, train accuracy = 26.62, test accuracy = 16.98
# Epoch = 10, train accuracy = 26.32, test accuracy = 16.89
# Epoch = 11, train accuracy = 26.07, test accuracy = 16.91
# Epoch = 12, train accuracy = 25.86, test accuracy = 17.03
# Epoch = 13, train accuracy = 25.69, test accuracy = 17.21
# Epoch = 14, train accuracy = 25.60, test accuracy = 17.47
# Epoch = 15, train accuracy = 25.55, test accuracy = 17.79
# Epoch = 16, train accuracy = 25.53, test accuracy = 18.14
# Epoch = 17, train accuracy = 25.55, test accuracy = 18.55
# Epoch = 18, train accuracy = 25.54, test accuracy = 18.55
# Epoch = 19, train accuracy = 25.59, test accuracy = 19.03
# Epoch = 20, train accuracy = 25.68, test accuracy = 19.51
# Epoch = 21, train accuracy = 25.80, test accuracy = 20.01
# Epoch = 22, train accuracy = 25.80, test accuracy = 20.01
# Epoch = 23, train accuracy = 25.93, test accuracy = 20.51
# Epoch = 24, train accuracy = 26.11, test accuracy = 21.03
# Epoch = 25, train accuracy = 26.11, test accuracy = 21.03
# Epoch = 26, train accuracy = 26.32, test accuracy = 21.57
# Epoch = 27, train accuracy = 26.32, test accuracy = 21.57
# Epoch = 28, train accuracy = 26.55, test accuracy = 22.11
# Epoch = 29, train accuracy = 26.56, test accuracy = 22.11
# Epoch = 30, train accuracy = 26.75, test accuracy = 22.45
# Epoch = 31, train accuracy = 26.82, test accuracy = 22.65
# Epoch = 32, train accuracy = 26.82, test accuracy = 22.65
# Epoch = 33, train accuracy = 27.11, test accuracy = 23.21
# Epoch = 34, train accuracy = 27.11, test accuracy = 23.21
# Epoch = 35, train accuracy = 27.11, test accuracy = 23.21
# Epoch = 36, train accuracy = 27.44, test accuracy = 23.77
# Epoch = 37, train accuracy = 27.44, test accuracy = 23.77
# Epoch = 38, train accuracy = 27.44, test accuracy = 23.77
# Epoch = 39, train accuracy = 27.44, test accuracy = 23.77
# Epoch = 40, train accuracy = 27.55, test accuracy = 24.00
# Epoch = 41, train accuracy = 27.72, test accuracy = 24.13
# Epoch = 42, train accuracy = 27.80, test accuracy = 24.33
# Epoch = 43, train accuracy = 27.81, test accuracy = 24.33
# Epoch = 44, train accuracy = 27.81, test accuracy = 24.33
# Epoch = 45, train accuracy = 27.87, test accuracy = 24.46
# Epoch = 46, train accuracy = 27.91, test accuracy = 24.53
# Epoch = 47, train accuracy = 27.96, test accuracy = 24.56
# Epoch = 48, train accuracy = 28.18, test accuracy = 24.89
# Epoch = 49, train accuracy = 28.18, test accuracy = 24.89
# Epoch = 50, train accuracy = 28.18, test accuracy = 24.89
# Epoch = 51, train accuracy = 28.18, test accuracy = 24.89
# Epoch = 52, train accuracy = 28.21, test accuracy = 24.95
# Epoch = 53, train accuracy = 28.23, test accuracy = 25.03
# Epoch = 54, train accuracy = 28.26, test accuracy = 25.04
# Epoch = 55, train accuracy = 28.26, test accuracy = 25.04
# Epoch = 56, train accuracy = 28.26, test accuracy = 25.05
# Epoch = 57, train accuracy = 28.27, test accuracy = 25.05
# Epoch = 58, train accuracy = 28.28, test accuracy = 25.06
# Epoch = 59, train accuracy = 28.29, test accuracy = 25.07
# Epoch = 60, train accuracy = 28.29, test accuracy = 25.08
# Epoch = 61, train accuracy = 28.29, test accuracy = 25.08
# Epoch = 62, train accuracy = 28.30, test accuracy = 25.08
# Epoch = 63, train accuracy = 28.31, test accuracy = 25.09
# Epoch = 64, train accuracy = 28.34, test accuracy = 25.10
# Epoch = 65, train accuracy = 28.36, test accuracy = 25.14
# Epoch = 66, train accuracy = 28.38, test accuracy = 25.17
# Epoch = 67, train accuracy = 28.38, test accuracy = 25.21
# Epoch = 68, train accuracy = 28.39, test accuracy = 25.24
# Epoch = 69, train accuracy = 28.43, test accuracy = 25.27
# Epoch = 70, train accuracy = 28.61, test accuracy = 25.58
# Epoch = 71, train accuracy = 28.62, test accuracy = 25.60
# Epoch = 72, train accuracy = 28.63, test accuracy = 25.60
# Epoch = 73, train accuracy = 28.63, test accuracy = 25.61
# Epoch = 74, train accuracy = 28.64, test accuracy = 25.63
# Epoch = 75, train accuracy = 28.62, test accuracy = 25.59
# Epoch = 76, train accuracy = 28.62, test accuracy = 25.60
# Epoch = 77, train accuracy = 28.63, test accuracy = 25.60
# Epoch = 78, train accuracy = 28.63, test accuracy = 25.62
# Epoch = 79, train accuracy = 28.64, test accuracy = 25.63
# Epoch = 80, train accuracy = 28.64, test accuracy = 25.64
# Epoch = 81, train accuracy = 28.64, test accuracy = 25.64
# Epoch = 82, train accuracy = 28.64, test accuracy = 25.65
# Epoch = 83, train accuracy = 28.64, test accuracy = 25.62
# Epoch = 84, train accuracy = 28.64, test accuracy = 25.62
# Epoch = 85, train accuracy = 28.64, test accuracy = 25.62
# Epoch = 86, train accuracy = 28.64, test accuracy = 25.62
# Epoch = 87, train accuracy = 28.64, test accuracy = 25.62
# Epoch = 88, train accuracy = 28.64, test accuracy = 25.63
# Epoch = 89, train accuracy = 28.65, test accuracy = 25.62
# Epoch = 90, train accuracy = 28.65, test accuracy = 25.61
# Epoch = 91, train accuracy = 28.65, test accuracy = 25.61
# Epoch = 92, train accuracy = 28.65, test accuracy = 25.61
# Epoch = 93, train accuracy = 28.65, test accuracy = 25.62
# Epoch = 94, train accuracy = 28.66, test accuracy = 25.64
# Epoch = 95, train accuracy = 28.66, test accuracy = 25.64
# Epoch = 96, train accuracy = 28.66, test accuracy = 25.65
# Epoch = 97, train accuracy = 28.66, test accuracy = 25.65
# Epoch = 98, train accuracy = 28.66, test accuracy = 25.65
# Epoch = 99, train accuracy = 28.66, test accuracy = 25.66
# Epoch = 100, train accuracy = 28.66, test accuracy = 25.66

# %%
#Creating dictionary with final predictions
final_predict_sj = sess.run(predict_sj, feed_dict={X_sj: X_sj_tests2})

final_predict_iq = sess.run(predict_iq, feed_dict={X_iq: X_iq_tests2})

# %%
#Creating file with test cases to be tested
submission = pd.read_csv("DengAI_Predicting_Disease_Spread_-_Submission_Format.csv",
                         index_col=[0, 1, 2])

submission.total_cases = np.concatenate([final_predict_sj, final_predict_iq])
submission.to_csv("version7withtf.csv")

# %%
from pandas import Series
from matplotlib import pyplot
print(sj_train_features.head())
sj_train_features.plot()
pyplot.show()
# Out:
#                 week_start_date   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# year weekofyear
# 1990 18              1990-04-30  0.122600  0.103725  0.198483  0.177617
#      19              1990-05-07  0.169900  0.142175  0.162357  0.155486
#      20              1990-05-14  0.032250  0.172967  0.157200  0.170843
#      21              1990-05-21  0.128633  0.245067  0.227557  0.235886
#      22              1990-05-28  0.196200  0.262200  0.251200  0.247340
#
#                  precipitation_amt_mm  reanalysis_air_temp_k  \
# year weekofyear
# 1990 18                         12.42             297.572857
#      19                         22.82             298.211429
#      20                         34.54             298.781429
#      21                         15.36             298.987143
#      22                          7.52             299.518571
#
#                  reanalysis_avg_temp_k  reanalysis_dew_point_temp_k  \
# year weekofyear
# 1990 18                     297.742857                   292.414286
#      19                     298.442857                   293.951429
#      20                     298.878571                   295.434286
#      21                     299.228571                   295.310000
#      22                     299.664286                   295.821429
#
#                  reanalysis_max_air_temp_k        ...          \
# year weekofyear                                   ...
# 1990 18                              299.8        ...
#      19                              300.9        ...
#      20                              300.5        ...
#      21                              301.4        ...
#      22                              301.9        ...
#
#                  reanalysis_precip_amt_kg_per_m2  \
# year weekofyear
# 1990 18                                    32.00
#      19                                    17.94
#      20                                    26.10
#      21                                    13.90
#      22                                    12.20
#
#                  reanalysis_relative_humidity_percent  \
# year weekofyear
# 1990 18                                     73.365714
#      19                                     77.368571
#      20                                     82.052857
#      21                                     80.337143
#      22                                     80.460000
#
#                  reanalysis_sat_precip_amt_mm  \
# year weekofyear
# 1990 18                                 12.42
#      19                                 22.82
#      20                                 34.54
#      21                                 15.36
#      22                                  7.52
#
#                  reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# year weekofyear
# 1990 18                                      14.012857           2.628571
#      19                                      15.372857           2.371429
#      20                                      16.848571           2.300000
#      21                                      16.672857           2.428571
#      22                                      17.210000           3.014286
#
#                  station_avg_temp_c  station_diur_temp_rng_c  \
# year weekofyear
# 1990 18                   25.442857                 6.900000
#      19                   26.714286                 6.371429
#      20                   26.714286                 6.485714
#      21                   27.471429                 6.771429
#      22                   28.942857                 9.371429
#
#                  station_max_temp_c  station_min_temp_c  station_precip_mm
# year weekofyear
# 1990 18                        29.4                20.0               16.0
#      19                        31.7                22.2                8.6
#      20                        32.2                22.8               41.4
#      21                        33.3                23.3                4.0
#      22                        35.0                23.9                5.8
#
# [5 rows x 21 columns]

# %%
from pandas import Series
from matplotlib import pyplot
print(iq_train_features.head())
iq_train_features.plot()
pyplot.show()
# Out:
#                 week_start_date   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# year weekofyear
# 2000 26              2000-07-01  0.192886  0.132257  0.340886  0.247200
#      27              2000-07-08  0.216833  0.276100  0.289457  0.241657
#      28              2000-07-15  0.176757  0.173129  0.204114  0.128014
#      29              2000-07-22  0.227729  0.145429  0.254200  0.200314
#      30              2000-07-29  0.328643  0.322129  0.254371  0.361043
#
#                  precipitation_amt_mm  reanalysis_air_temp_k  \
# year weekofyear
# 2000 26                         25.41             296.740000
#      27                         60.61             296.634286
#      28                         55.52             296.415714
#      29                          5.60             295.357143
#      30                         62.76             296.432857
#
#                  reanalysis_avg_temp_k  reanalysis_dew_point_temp_k  \
# year weekofyear
# 2000 26                     298.450000                   295.184286
#      27                     298.428571                   295.358571
#      28                     297.392857                   295.622857
#      29                     296.228571                   292.797143
#      30                     297.635714                   293.957143
#
#                  reanalysis_max_air_temp_k        ...          \
# year weekofyear                                   ...
# 2000 26                              307.3        ...
#      27                              306.6        ...
#      28                              304.5        ...
#      29                              303.6        ...
#      30                              307.0        ...
#
#                  reanalysis_precip_amt_kg_per_m2  \
# year weekofyear
# 2000 26                                    43.19
#      27                                    46.00
#      28                                    64.77
#      29                                    23.96
#      30                                    31.80
#
#                  reanalysis_relative_humidity_percent  \
# year weekofyear
# 2000 26                                     92.418571
#      27                                     93.581429
#      28                                     95.848571
#      29                                     87.234286
#      30                                     88.161429
#
#                  reanalysis_sat_precip_amt_mm  \
# year weekofyear
# 2000 26                                 25.41
#      27                                 60.61
#      28                                 55.52
#      29                                  5.60
#      30                                 62.76
#
#                  reanalysis_specific_humidity_g_per_kg  reanalysis_tdtr_k  \
# year weekofyear
# 2000 26                                      16.651429           8.928571
#      27                                      16.862857          10.314286
#      28                                      17.120000           7.385714
#      29                                      14.431429           9.114286
#      30                                      15.444286           9.500000
#
#                  station_avg_temp_c  station_diur_temp_rng_c  \
# year weekofyear
# 2000 26                   26.400000                10.775000
#      27                   26.900000                11.566667
#      28                   26.800000                11.466667
#      29                   25.766667                10.533333
#      30                   26.600000                11.480000
#
#                  station_max_temp_c  station_min_temp_c  station_precip_mm
# year weekofyear
# 2000 26                        32.5                20.7                3.0
#      27                        34.0                20.8               55.6
#      28                        33.0                20.7               38.1
#      29                        31.5                14.7               30.0
#      30                        33.3                19.1                4.0
#
# [5 rows x 21 columns]

# %%
# %matplotlib inline

from __future__ import print_function
from __future__ import division

import pandas as pd
import numpy as np

from matplotlib import pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
import statsmodels.api as sm
# Out:
# /Users/hannahsaghir/anaconda/lib/python3.6/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
#Attempt to plot actual vs. predicted 

figs, axes = plt.subplots(nrows=2, ncols=1)

# plot sj
sj_train_features['fitted'] = predict_sj
predict_sj.fitted.plot(ax=axes[0], label="Predictions")
sj_train_features.total_cases.plot(ax=axes[0], label="Actual")

# plot iq
iq_train_features['fitted'] = predict_iq
predict_iq.fitted.plot(ax=axes[1], label="Predictions")
iq_train_features.total_cases.plot(ax=axes[1], label="Actual")

plt.suptitle("Dengue Predicted Cases vs. Actual Cases")
plt.legend()
# Out:
# /Users/hannahsaghir/anaconda/lib/python3.6/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-b34c016a53f9> in <module>()
#       5 # plot sj
#       6 sj_train_features['fitted'] = predict_sj
# ----> 7 predict_sj.fitted.plot(ax=axes[0], label="Predictions")
#       8 sj_train_features.total_cases.plot(ax=axes[0], label="Actual")
#       9
#
# AttributeError: 'Tensor' object has no attribute 'fitted'
